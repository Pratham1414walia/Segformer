# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.7.22)

# %%
from PIL import Image
import os

for file_name in os.listdir('testo'):
    if file_name.endswith('.JPG' or '.jpg' or '.jpeg' or 'jPG'):
        img = Image.open('testo/' + file_name)
        img.save('testo/' + file_name[:-4] + '.png', 'PNG')

# %%
import tensorflow as tf

# %%
from tensorflow.keras import backend
import matplotlib.pyplot as plt

# %%
def load_image_file(image_path, mask_path):
    image = tf.io.read_file(image_path)
    mask = tf.io.read_file(mask_path)

    image = tf.image.decode_jpeg(image, channels=3)
    mask = tf.image.decode_png(mask, channels=1)

    return {"image": image, "segmentation_mask": mask}

# %%
train_image_dir = "/content/original"
train_mask_dir = "/content/mask"
# valid_image_dir = "/content/valido"
# valid_mask_dir = "/content/validm"
# test_image_dir = "/content/testo"
# test_mask_dir = "/content/testm"

# Define list of image and mask file names
train_image_names = sorted(os.listdir(train_image_dir))
train_mask_names = sorted(os.listdir(train_mask_dir))

# valid_image_names = sorted(os.listdir(valid_image_dir))
# valid_mask_names = sorted(os.listdir(valid_mask_dir))

# test_image_names = sorted(os.listdir(test_image_dir))
# test_mask_names = sorted(os.listdir(test_mask_dir))

train_pairs = []
for img_name in train_image_names:
    # Check if image file name matches mask file name
    mask_name = img_name.replace("image", "mask")
    if mask_name in train_mask_names:
        train_pairs.append((os.path.join(train_image_dir, img_name), os.path.join(train_mask_dir, mask_name)))

# valid_pairs = []
# for img_name in valid_image_names:
#     # Check if image file name matches mask file name
#     mask_name = img_name.replace("image", "mask")
#     if mask_name in valid_mask_names:
#         valid_pairs.append((os.path.join(valid_image_dir, img_name), os.path.join(valid_mask_dir, mask_name)))

# test_pairs = []
# for img_name in test_image_names:
#     # Check if image file name matches mask file name
#     mask_name = img_name.replace("image", "mask")
#     if mask_name in test_mask_names:
#         test_pairs.append((os.path.join(test_image_dir, img_name), os.path.join(test_mask_dir, mask_name)))

# Load image and mask data from file paths
data_train = [load_image_file(image_path, mask_path) for image_path, mask_path in train_pairs]
# data_valid = [load_image_file(image_path, mask_path) for image_path, mask_path in valid_pairs]
# data_test = [load_image_file(image_path, mask_path) for image_path, mask_path in test_pairs]

len(data_train)
# Out:
# 999

# %%
valid_image_dir = "/content/valido"
valid_mask_dir = "/content/validm"
test_image_dir = "/content/testo"
test_mask_dir = "/content/testm"

# Define list of image and mask file names


valid_image_names = sorted(os.listdir(valid_image_dir))
valid_mask_names = sorted(os.listdir(valid_mask_dir))

test_image_names = sorted(os.listdir(test_image_dir))
test_mask_names = sorted(os.listdir(test_mask_dir))


valid_pairs = []
for img_name in valid_image_names:
    # Check if image file name matches mask file name
    mask_name = img_name.replace("image", "mask")
    if mask_name in valid_mask_names:
        valid_pairs.append((os.path.join(valid_image_dir, img_name), os.path.join(valid_mask_dir, mask_name)))

test_pairs = []
for img_name in test_image_names:
    # Check if image file name matches mask file name
    mask_name = img_name.replace("image", "mask")
    if mask_name in test_mask_names:
        test_pairs.append((os.path.join(test_image_dir, img_name), os.path.join(test_mask_dir, mask_name)))

# Load image and mask data from file paths

data_valid = [load_image_file(image_path, mask_path) for image_path, mask_path in valid_pairs]
data_test = [load_image_file(image_path, mask_path) for image_path, mask_path in test_pairs]

len(data_valid)
# Out:
# 23

# %%
len(data_test)
# Out:
# 24

# %%
import os

path = "valido"
counter = 1

for filename in os.listdir(path):
    if os.path.isfile(os.path.join(path, filename)):
        os.rename(os.path.join(path, filename), os.path.join(path, f"image{counter:03}.png"))
        counter += 1

# %%
cnt = 0
for image_path, mask_path in train_pairs:
  print(image_path)
# Out:
# /content/output_folder/.ipynb_checkpoints
# /content/output_folder/image_01.png

# %%
image_size = 256
mean = tf.constant([0.485, 0.456, 0.406])
std = tf.constant([0.229, 0.224, 0.225])


def normalize(input_image, input_mask):
    input_image = tf.image.convert_image_dtype(input_image, tf.float32)
    input_image = (input_image - mean) / tf.maximum(std, backend.epsilon())
    input_mask = input_mask / 255
    return input_image, input_mask


def load_image(datapoint):
    input_image = tf.image.resize(datapoint["image"], (image_size, image_size))
    input_mask = tf.image.resize(
        datapoint["segmentation_mask"],
        (image_size, image_size),
        method="bilinear",
    )
    input_image, input_mask = normalize(input_image, input_mask)
    input_image = tf.transpose(input_image, (2, 0, 1))

    return {"pixel_values": input_image, "labels": tf.squeeze(input_mask)}

# %%
train_data = [load_image(datapoint) for datapoint in data_train]
# valid_data = [load_image(datapoint) for datapoint in data_valid]
# test_data = [load_image(datapoint) for datapoint in data_test]

# %%
valid_data = [load_image(datapoint) for datapoint in data_valid]
test_data = [load_image(datapoint) for datapoint in data_test]

# %%
plt.imshow(train_data[0]["labels"])

# %%
def generator_train():
    for datapoint in train_data:
        yield datapoint

def generator_valid():
    for datapoint in valid_data:
        yield datapoint

def generator_test():
    for datapoint in test_data:
        yield datapoint

# %%
batch_size = 4
auto = tf.data.AUTOTUNE

train_ds = tf.data.Dataset.from_generator(generator_train, output_types={"pixel_values": tf.float32, "labels": tf.int32}).cache().shuffle(batch_size * 10).batch(batch_size).prefetch(auto)

valid_ds = tf.data.Dataset.from_generator(generator_valid, output_types={"pixel_values": tf.float32, "labels": tf.int32}).batch(batch_size).prefetch(auto)

test_ds = tf.data.Dataset.from_generator(generator_test, output_types={"pixel_values": tf.float32, "labels": tf.int32}).batch(batch_size).prefetch(auto)

# %%
print(train_ds.element_spec)
# Out:
# {'pixel_values': TensorSpec(shape=<unknown>, dtype=tf.float32, name=None), 'labels': TensorSpec(shape=<unknown>, dtype=tf.int32, name=None)}

# %%
def display(display_list):
    plt.figure(figsize=(15, 15))

    title = ["Input Image", "True Mask", "Predicted Mask"]

    for i in range(len(display_list)):
        plt.subplot(1, len(display_list), i + 1)
        plt.title(title[i])
        plt.imshow(tf.keras.utils.array_to_img(display_list[i]))
        plt.axis("off")
    plt.show()


for samples in train_ds.take(2):
    sample_image, sample_mask = samples["pixel_values"][0], samples["labels"][0]
    sample_image = tf.transpose(sample_image, (1, 2, 0))
    sample_mask = tf.expand_dims(sample_mask, -1)
    display([sample_image, sample_mask])
    print(sample_image.shape)
# Out:
# (256, 256, 3)
# (256, 256, 3)

# %%
from transformers import TFSegformerForSemanticSegmentation

model_checkpoint = "nvidia/mit-b1"
id2label =  {0: "outer", 1: "landslide"}
label2id = {label: id for id, label in id2label.items()}
num_labels = len(id2label)
model = TFSegformerForSemanticSegmentation.from_pretrained(
    model_checkpoint,
    num_labels=num_labels,
    id2label=id2label,
    label2id=label2id,
    ignore_mismatched_sizes=True,

)
# Out:
# config.json:   0%|          | 0.00/70.0k [00:00<?, ?B/s]
# tf_model.h5:   0%|          | 0.00/54.9M [00:00<?, ?B/s]
# WARNING:tensorflow:5 out of the last 5 calls to <function Conv._jit_compiled_convolution_op at 0x7bdcc2066a70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function Conv._jit_compiled_convolution_op at 0x7bdcc2067c70> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Some layers from the model checkpoint at nvidia/mit-b1 were not used when initializing TFSegformerForSemanticSegmentation: ['classifier']
# - This IS expected if you are initializing TFSegformerForSemanticSegmentation from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFSegformerForSemanticSegmentation from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some layers of TFSegformerForSemanticSegmentation were not initialized from the model checkpoint at nvidia/mit-b1 and are newly initialized: ['decode_head']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
lr = 0.0006
epochs = 5
optimizer = tf.keras.optimizers.Adam(learning_rate=lr)
model.compile(optimizer=optimizer)

# %%
from IPython.display import clear_output


def create_mask(pred_mask):
    pred_mask = tf.math.argmax(pred_mask, axis=1)
    pred_mask = tf.expand_dims(pred_mask, -1)
    return pred_mask[0]


def show_predictions(dataset=None, num=1):
    if dataset:
        for sample in dataset.take(num):
            images, masks = sample["pixel_values"], sample["labels"]
            masks = tf.expand_dims(masks, -1)
            pred_masks = model.predict(images).logits
            images = tf.transpose(images, (0, 2, 3, 1))
            display([images[0], masks[0], create_mask(pred_masks)])
    else:
        display(
            [
                sample_image,
                sample_mask,
                create_mask(model.predict(tf.expand_dims(sample_image, 0))),
            ]
        )


class DisplayCallback(tf.keras.callbacks.Callback):
    def __init__(self, dataset, **kwargs):
        super().__init__(**kwargs)
        self.dataset = dataset

    def on_epoch_end(self, epoch, logs=None):
        clear_output(wait=True)
        show_predictions(self.dataset)
        print("\nSample Prediction after epoch {}\n".format(epoch + 1))

# %%
history = model.fit(
    train_ds,
    # validation_data=valid_ds,
    # callbacks=[DisplayCallback(test_ds)],
    epochs=epochs,
)
# Out:
# Epoch 1/5
# 250/250 [==============================] - 79s 114ms/step - loss: 0.1431
# Epoch 2/5
# 250/250 [==============================] - 25s 101ms/step - loss: 0.0768
# Epoch 3/5
# 250/250 [==============================] - 26s 104ms/step - loss: 0.0675
# Epoch 4/5
# 250/250 [==============================] - 25s 102ms/step - loss: 0.0642
# Epoch 5/5
# 250/250 [==============================] - 26s 105ms/step - loss: 0.0620

# %%
history = model.fit(
    train_ds,
    validation_data=valid_ds,
    callbacks=[DisplayCallback(test_ds)],
    epochs=1,
)
# Out:
# 1/1 [==============================] - 3s 3s/step
# Sample Prediction after epoch 1
#
# 250/250 [==============================] - 42s 166ms/step - loss: 0.0601 - val_loss: 0.0548

# %%
model.save('Prototype1.h')

# %%
from google.colab import files

# Download the model file
files.download("Prototype1.h")

# %%
model.save_weights("/content/segformer-5-b1.h5")

# %%
plt.style.use("seaborn")

def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('Model '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

plt.subplots(figsize=(8,8))
plt.tight_layout()
display_training_curves(history.history['loss'], history.history['val_loss'], 'Loss', 111)
plt.savefig("train_eval_plot_segformer-5-b1.jpg")
# Out:
# <ipython-input-34-2df983d90a25>:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
show_predictions(valid_ds, 10)
# Out:
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 87ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 90ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 87ms/step

# %%
files.download("/content/original")

# %%
files.download("/content/mask")

# %%
# !zip -r /content/original1.zip /content/original
# Out:
#   adding: content/original/ (stored 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_20902934.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_17826379.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_19978545.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22995998.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_11756049.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22262504.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_11319811.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_18706009.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_7402448.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_13175640.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22838607.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_15360520.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_12266777.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_9407185.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22921829.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_8980704.JPG (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_21733717.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_9411769.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_20101731.JPG (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22932390.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_21005349.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22529362.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_22921829.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22633580.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_21027938.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_19980453.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_19443610.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22223291.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_10209332.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22956254.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22529362.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22732538.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_11319811.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_17544984.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22231585.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22633580.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_20656012.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_18864247.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_9034046.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_17490328.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_12020481.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_18054002.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_20162350.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_12359830.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_8231668.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22973355.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_7774274.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_10988503.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_21541476.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_8737266.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_10463104.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_6806112.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_15411639.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_8080939.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22921829.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22620825.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_21648552.JPG (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22616281.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_17743754.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_20621671.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_18705424.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_16239698.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_15411639.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_21733717.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_21546152.png (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_22949014.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_22921829.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_19105411.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_13294533.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22891940.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_15343969.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_15300193.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_14311405.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_14585526.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_17341533.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_14983078.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_14585526.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_11361790.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_14598050.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_14809997.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_12965830.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_23043359.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22921829.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22936604.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_15411639.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_13294533.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_20358523.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_6556628.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_15360520.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_18705424.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_7745488.JPG (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_17341533.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_17051589.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_13054205.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_10408283.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_10354324.png (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22949252.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22838607.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_9953345.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_11756049.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_16816041.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22978304.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_10785396.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_18984138.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22171944.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_21005349.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_10785396.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_7402448.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_565559.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_10651679.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_13713434.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_10572495.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_21662816.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_20456728.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_17696458.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_18706009.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_4007547.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_21657629.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22803965.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_12387478.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_21879111.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_22951117.png (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_10248573.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_17221571.JPG (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_20465261.JPG (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22684644.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_19242142.JPG (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_14051594.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_8814839.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_22231585.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_16854033.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_8817269.JPG (deflated 1%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_22822435.JPG (deflated 1%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_19311897.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_21027938.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_19105411.JPG (deflated 0%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_6677454.JPG (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_21344988.png (deflated 0%)
#   adding: content/original/DMI_OS_LOWER_REFLECTED_IR_19443610.JPG (deflated 1%)
#   adding: content/original/DMI_OS_UPPER_REFLECTED_IR_18144122.JPG (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_7745488.png (deflated 1%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_9034046.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR_17551782.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_19443610.png (deflated 0%)
#   adding: content/original/DMI_OD_UPPER_REFLECTED_IR_17270020.png (deflated 0%)
#   adding: content/original/DMI_OD_LOWER_REFLECTED_IR